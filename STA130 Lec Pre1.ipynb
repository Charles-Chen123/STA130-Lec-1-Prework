# %%
import pandas as pd

# URL for a publicly available housing prices dataset
url = "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv"

# Load the dataset into a pandas DataFrame
housing_data = pd.read_csv(url)

# Display the first few rows of the dataset
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import pandas as pd

# Replace 'path_to_your_file' with the actual file path on your machine
file_path = "path_to_your_file/housing.csv"

# Load the dataset
file_path = "/Users/YourUsername/Desktop/datasets/housing.csv"

# Get column names and the number of rows and columns
columns = housing_data.columns
data_shape = housing_data.shape

print("Columns in the dataset:")
print(columns)
print("\nNumber of rows and columns:")
print(data_shape)
# Out:
# Columns in the dataset:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')
#
# Number of rows and columns:
# (20640, 10)

# %%
import pandas as pd



# Load the dataset
file_path = "/Users/YourUsername/Desktop/datasets/housing.csv"

# Get column names and the number of rows and columns
columns = housing_data.columns
data_shape = housing_data.shape

print("Columns in the dataset:")
print(columns)
print("\nNumber of rows and columns:")
print(data_shape)
# Out:
# Columns in the dataset:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')
#
# Number of rows and columns:
# (20640, 10)

# %%
import pandas as pd

# 1. View the first few rows
print(df.head())

# 2. Get basic information about the dataset
df.info()

# 3. Get summary statistics for numeric columns
df.describe()

# 4. Check for missing values in each column
df.isnull().sum()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# Check the data types of each column
print(df.dtypes)

# Select only non-numeric columns
non_numeric_columns = df.select_dtypes(include=['object', 'category']).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
# Non-numeric columns: Index(['ocean_proximity'], dtype='object')

# %%
# Select only numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Check for missing values in numeric columns
missing_values_in_numeric = numeric_columns.isnull().sum()
print("Missing values in numeric columns:")
print(missing_values_in_numeric)
# Out:
# Missing values in numeric columns:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
Difference
# "Attribute" is the firm information or property of an object. It is like a fixed data. 
# "Method" is a method to gather the information or compute the information of an object. It is like an action.
